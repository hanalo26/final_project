# %% [markdown]
# ### **(0) 환경 설정**

# %%
# ========================================
# 라이브러리 로드
# ========================================
import json
from pprint import pprint

import pandas as pd

# %%
df = pd.read_csv("../../data/IT도메인 기업리스트.csv", encoding="cp949")

df.head()
# Out:
#      name              amount              분류 Unnamed: 3
# 0      KT  19,324,000,000,000         네트워크·통신        NaN
# 1  LG유플러스  14,204,200,000,000         네트워크·통신        NaN
# 2   SK텔레콤  12,051,100,000,000         네트워크·통신        NaN
# 3   NAVER   7,019,300,000,000          포털·플랫폼        네이버
# 4   삼성SDS   5,464,600,000,000  솔루션·SI·CRM·ERP        NaN

# %%
# json 파일 열기
with open('../../outputs/checkpoint_IT(배치처리).json', 'r', encoding='utf-8') as f:
    data_it = json.load(f)
    
pprint(data_it)
# Out:
# [{'channels': [{'channel_handle': '@sktelecom',
#                 'channel_id': 'UCA5vKQkvC9zlTDOSNtoMdCQ',
#                 'channel_name': 'SK telecom',
#                 'channel_reason': "SK텔레콤의 메인 공식 유튜브 채널로, 채널 설명에 'SK telecom 공식 "
#                                   "YouTube 채널'이라고 명시되어 있으며 113만 명 이상의 구독자를 "
#                                   '보유하고 있습니다. 기업 홍보, 서비스 소개, ESG 활동 등 전반적인 소식을 '
#                                   '다룹니다.',
#                 'channel_url': 'https://www.youtube.com/@sktelecom'},
#                {'channel_handle': '@skaisummit2025',
#                 'channel_id': 'UCqi8fAllvDe9-QCDlhxSg8Q',
#                 'channel_name': 'SK AI SUMMIT 2025',
#                 'channel_reason': "SK텔레콤이 주최하는 글로벌 AI 컨퍼런스인 'SK AI SUMMIT'의 공식 "
#                                   '채널입니다. AI 기술과 비전을 공유하는 공식 행사 채널로 확인되었습니다.',
#                 'channel_url': 'https://www.youtube.com/@skaisummit2025'}],
#   'company_name': 'SK텔레콤 (SK Telecom)',
#   'has_official': True,
# ...

# %%
# 식품기업
df2 = pd.read_csv('../../data/식품기업리스트top60.csv', encoding='utf-8')

df2.head(3)
# Out:
#            name    amount       KSIC
# 0   주식회사 지에스리테일  11378032    체인화 편의점
# 1  주식회사 비지에프리테일   8592136    체인화 편의점
# 2  씨제이제일제당 주식회사   7598277  기타 식품 제조업
