# %% [markdown]
# ### **(0) 환경 설정**

# %%
# ========================================
# 라이브러리 로드
# ========================================
from IPython.display import display
from pprint import pprint

import pandas as pd

# %%
# FnB 도메인에 속하는 기업 영상들 중 숏츠 영상 필터링
df_food = pd.read_csv("../../data/filtered_food_with_redirect.csv", encoding='utf-8')

# domain 컬럼 추가
df_food['domain'] = 'FnB'

print(df_food.shape)
print('-'*30)
pprint(df_food.info())
print('-'*30)
pprint(df_food['verdict'].value_counts())
# Out:
# (10852, 26)
# ------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 10852 entries, 0 to 10851
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  10852 non-null  int64
#  1   video_id                    10852 non-null  str
#  2   title                       10852 non-null  str
#  3   channel_id                  10852 non-null  str
#  4   channel_title               10852 non-null  str
#  5   description                 10215 non-null  str
#  6   upload_date                 10852 non-null  str
#  7   tags                        4507 non-null   str
#  8   category_id                 10852 non-null  int64
#  9   view_count                  10852 non-null  int64
#  10  like_count                  9990 non-null   float64
#  11  comment_count               10691 non-null  float64
#  12  duration                    10852 non-null  str
#  13  definition                  10852 non-null  str
#  14  license                     10852 non-null  str
#  15  embeddable                  10852 non-null  bool
#  16  has_paid_product_placement  10852 non-null  bool
#  17  thumbnail                   10852 non-null  str
#  18  thumbnail_h                 10852 non-null  int64
#  19  thumbnail_w                 10852 non-null  int64
#  20  caption                     10852 non-null  bool
#  21  year                        10852 non-null  int64
#  22  verdict                     10850 non-null  str
#  23  reasoning                   10850 non-null  str
#  24  final_url                   10850 non-null  str
#  25  domain                      10852 non-null  str
# dtypes: bool(3), float64(2), int64(6), str(15)
# memory usage: 12.2 MB
# None
# ------------------------------
# verdict
# shorts      5534
# longform    5316
# Name: count, dtype: int64

# %%
df_food_shorts = df_food[df_food['verdict'] == 'shorts']

print(len(df_food_shorts))
# Out:
# 5534

# %%
# IT 도메인에 속하는 기업 영상들 중 숏츠 영상 필터링
df_it = pd.read_csv("../../data/filtered_it_with_redirect.csv", encoding='utf-8')

# domain 컬럼 추가
df_it['domain'] = 'IT'

print(df_it.shape)
print('-'*30)
pprint(df_it.info())
print('-'*30)
pprint(df_it['verdict'].value_counts())
# Out:
# (8431, 26)
# ------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 8431 entries, 0 to 8430
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  8431 non-null   int64
#  1   video_id                    8431 non-null   str
#  2   title                       8431 non-null   str
#  3   channel_id                  8431 non-null   str
#  4   channel_title               8431 non-null   str
#  5   description                 7858 non-null   str
#  6   upload_date                 8431 non-null   str
#  7   tags                        5550 non-null   str
#  8   category_id                 8431 non-null   int64
#  9   view_count                  8431 non-null   int64
#  10  like_count                  7281 non-null   float64
#  11  comment_count               7231 non-null   float64
#  12  duration                    8431 non-null   str
#  13  definition                  8431 non-null   str
#  14  license                     8431 non-null   str
#  15  embeddable                  8431 non-null   bool
#  16  has_paid_product_placement  8431 non-null   bool
#  17  thumbnail                   8431 non-null   str
#  18  thumbnail_h                 8431 non-null   int64
#  19  thumbnail_w                 8431 non-null   int64
#  20  caption                     8431 non-null   bool
#  21  year                        8431 non-null   int64
#  22  verdict                     8431 non-null   str
#  23  reasoning                   8431 non-null   str
#  24  final_url                   8431 non-null   str
#  25  domain                      8431 non-null   str
# dtypes: bool(3), float64(2), int64(6), str(15)
# memory usage: 10.7 MB
# None
# ------------------------------
# verdict
# longform    5958
# shorts      2473
# Name: count, dtype: int64

# %%
df_it_shorts = df_it[df_it['verdict'] == 'shorts']

print(len(df_it_shorts))
# Out:
# 2473

# %% [markdown]
# ---
# #### 모델 성능 테스트용 데이터셋 제작
# - IT 도메인 영상: 3개
# - Food 도메인 영상: 3개

# %%
it_sample = df_it_shorts.iloc[422:425]
food_sample = df_food_shorts.iloc[424:427]

display(it_sample)
print("="*60)
display(food_sample)
# Out:
#       Unnamed: 0     video_id                                         title  \
# 1183        1630  knCQBlBKSRM                 [B 다이렉트샵] 필사즉생의 각오로 임하는 발음 연습
# 1184        1631  NCVxpXxTMSU                 [B 다이렉트샵] 고음불가? NO! 발음불가? YES
# 1193        1640  LRmLOsmMHts  에이닷과 대화하며 즐기는 B tv IPTV로 바꾸자! (문의 1600-2345)
#
#                     channel_id channel_title  \
# 1183  UCwR9k7QggFEfeHkvTR31JcA  SK브로드밴드_B tv
# 1184  UCwR9k7QggFEfeHkvTR31JcA  SK브로드밴드_B tv
# 1193  UCwR9k7QggFEfeHkvTR31JcA  SK브로드밴드_B tv
#
#                                             description  \
# 1183  죽고자 하면 산다고 하잖아요\n그래서 죽기살기로 연습해달라 했죠.\n그렇게 하다보니...
# 1184  연습 50일 째. 광고주 담당자 얼굴에서\n안색이라는 것이 점차 사라져가고 있습니다...
# 1193  아직도 IPTV로 안 바꾸셨어요?\n\n주인공이 뛰는 미국 영화가 뭐였더라?\n궁금...
#
#                     upload_date tags  category_id  view_count  ...  \
# 1183  2026-02-13 04:20:50+00:00  NaN            1     3615612  ...
# 1184  2026-02-13 04:20:46+00:00  NaN            1     3041416  ...
# 1193  2026-01-08 07:58:00+00:00  NaN            1      261176  ...
#
#       has_paid_product_placement  \
# 1183                       False
# 1184                       False
# 1193                       False
#
#                                              thumbnail thumbnail_h  \
# 1183  https://i.ytimg.com/vi/knCQBlBKSRM/hqdefault.jpg         360
# 1184  https://i.ytimg.com/vi/NCVxpXxTMSU/hqdefault.jpg         360
# 1193  https://i.ytimg.com/vi/LRmLOsmMHts/hqdefault.jpg         360
#
#      thumbnail_w caption  year  verdict           reasoning  \
# 1183         480   False  2026   shorts  kept /shorts route
# 1184         480   False  2026   shorts  kept /shorts route
# 1193         480   False  2026   shorts  kept /shorts route
#
#                                        final_url  domain
# 1183  https://www.youtube.com/shorts/knCQBlBKSRM      IT
# 1184  https://www.youtube.com/shorts/NCVxpXxTMSU      IT
# 1193  https://www.youtube.com/shorts/LRmLOsmMHts      IT
#
# [3 rows x 26 columns]
# ============================================================
#      Unnamed: 0     video_id  \
# 655         655  twi9zUxsXu0
# 656         656  Xfu1kCID0Ls
# 657         657  MIJR3Dm0YOk
#
#                                                  title  \
# 655  🍓 + 🍫 +🌽 + 🥘 = 😋  | CU X 프롬서희 이모티콘 먹방 2월 3주차 #...
# 656   [연예뉴스] 두 아티스트의 불화설이 제기돼... | CU콘서트 #4강 #B조 #3라운드
# 657            학부모 참관수업에서 당황한 이유 | CU콘서트 #4강 #B조 #3라운드
#
#                    channel_id channel_title  \
# 655  UCsM07dUwo0WOWhFbVsG8K6A     CU [씨유튜브]
# 656  UCsM07dUwo0WOWhFbVsG8K6A     CU [씨유튜브]
# 657  UCsM07dUwo0WOWhFbVsG8K6A     CU [씨유튜브]
#
#                                            description  \
# 655  이렇게 귀엽기 잇씨유? (✿◡‿◡)\n\n귀여운 꽃카 콜라보 신상과\n한국인은 못참...
# 656  스탠딩 코미디의 부활! [CU콘서트]\n\nCU 공채 개그맨에 한 걸음 더 다가선\...
# 657  스탠딩 코미디의 부활! [CU콘서트]\n\nCU 공채 개그맨에 한 걸음 더 다가선\...
#
#                    upload_date  \
# 655  2023-02-15 09:00:18+00:00
# 656  2023-02-13 09:00:40+00:00
# 657  2023-02-13 09:00:24+00:00
#
#                                                   tags  category_id  \
# 655  먹방, MUKBANG, mukbang, 이모지먹방, 이모티콘먹방, emoji, em...           24
# 656  CU편의점, CU, 씨유, 헤이루, Heyroo, cu콘서트, cuconcert, ...           24
# 657  CU편의점, CU, 씨유, 헤이루, Heyroo, cu콘서트, cuconcert, ...           24
#
#      view_count  ...  has_paid_product_placement  \
# 655      189406  ...                       False
# 656       46925  ...                       False
# 657      111804  ...                       False
#
#                                             thumbnail thumbnail_h thumbnail_w  \
# 655  https://i.ytimg.com/vi/twi9zUxsXu0/hqdefault.jpg         360         480
# 656  https://i.ytimg.com/vi/Xfu1kCID0Ls/hqdefault.jpg         360         480
# 657  https://i.ytimg.com/vi/MIJR3Dm0YOk/hqdefault.jpg         360         480
#
#     caption  year  verdict           reasoning  \
# 655   False  2023   shorts  kept /shorts route
# 656   False  2023   shorts  kept /shorts route
# 657   False  2023   shorts  kept /shorts route
#
#                                       final_url  domain
# 655  https://www.youtube.com/shorts/twi9zUxsXu0     FnB
# 656  https://www.youtube.com/shorts/Xfu1kCID0Ls     FnB
# 657  https://www.youtube.com/shorts/MIJR3Dm0YOk     FnB
#
# [3 rows x 26 columns]

# %%
df_test = pd.concat([it_sample, food_sample], ignore_index=True)
df_test.to_csv("../Haeun/video_analysis/data/shorts-analysis_test-1.csv", index=False, encoding='utf-8-sig')
