# %%
from IPython.display import display
from pprint import pprint

import pandas as pd

# %%
df_korean = pd.read_csv("../../data/test-case_comment-1.csv", encoding='utf-8')

df_korean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   video_id    40 non-null     str
#  1   comment_id  40 non-null     str
#  2   author      40 non-null     str
#  3   comment     40 non-null     str
#  4   likes       40 non-null     int64
#  5   date        40 non-null     str
#  6   domain      40 non-null     str
# dtypes: int64(1), str(6)
# memory usage: 13.6 KB

# %%
df_abroad = pd.read_csv("../../data/test-case_comment-3_외국어.csv", encoding='utf-8')

df_abroad.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   video_id    780 non-null    str
#  1   comment_id  780 non-null    str
#  2   author      780 non-null    str
#  3   comment     780 non-null    str
#  4   likes       780 non-null    int64
#  5   date        780 non-null    str
#  6   domain      780 non-null    str
# dtypes: int64(1), str(6)
# memory usage: 132.1 KB

# %% [markdown]
# ---

# %%
# 테스트 데이터 추출
df_korean_test1 = df_korean.iloc[:10]
df_abroad_test1 = df_abroad.iloc[:5]

# %%
df_test = pd.concat([df_korean_test1, df_abroad_test1], ignore_index=True)
df_test.to_csv("../../data/test-case_comment-4_언어혼용.csv", index=False, encoding='utf-8-sig')

print(df_test.shape)
# Out:
# (15, 7)
