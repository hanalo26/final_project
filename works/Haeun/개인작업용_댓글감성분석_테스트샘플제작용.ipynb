# %%
from IPython.display import display
from pprint import pprint

import pandas as pd

# %%
df_comment_food = pd.read_csv("../../data/food_redirect_comment.csv", encoding='utf-8')

df_comment_food.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 565177 entries, 0 to 565176
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   video_id    565177 non-null  str
#  1   comment_id  565177 non-null  str
#  2   author      565177 non-null  str
#  3   comment     565150 non-null  str
#  4   likes       565177 non-null  int64
#  5   date        565177 non-null  str
# dtypes: int64(1), str(5)
# memory usage: 142.6 MB

# %%
df_comment_it = pd.read_csv("../../data/it_redirect_comment.csv", encoding='utf-8')

df_comment_it.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 158792 entries, 0 to 158791
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   video_id    158792 non-null  str
#  1   comment_id  158792 non-null  str
#  2   author      158792 non-null  str
#  3   comment     158778 non-null  str
#  4   likes       158792 non-null  int64
#  5   date        158792 non-null  str
# dtypes: int64(1), str(5)
# memory usage: 41.4 MB

# %% [markdown]
# ---

# %%
# 도메인 컬럼 추가
df_comment_food['domain'] = 'FnB'
df_comment_it['domain'] = 'IT'

# %%
# 테스트 데이터 추출
df_comment_it_test1 = df_comment_it.iloc[565141:565151]
df_comment_it_test2 = df_comment_it.iloc[15520:15530]
df_comment_food_test1 = df_comment_food.iloc[1522:1542]
df_comment_food_test2 = df_comment_food.iloc[15552:15562]

# %%
df_test = pd.concat([df_comment_it_test1, df_comment_it_test2, df_comment_food_test1, df_comment_food_test2], ignore_index=True)
df_test.to_csv("../../data/test-case_comment-1.csv", index=False, encoding='utf-8-sig')

print(df_test.shape)
# Out:
# (40, 7)
